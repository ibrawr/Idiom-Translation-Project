# %% [markdown]
# # 07_experiment_tracking
#
# Experiment tracking and deployment summary.

# %% [markdown]
# ## Step 1: Generate the final experiment summary
# This pulls values from the training logs, checkpoints, and evaluation results.

# %%
# !python experiment_logger.py --config config.yaml
# Out:
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# Saved experiment summary to: results_summary.csv
# ------------------------------------------------------------
# model_type: full_ft
# base_model: google/mt5-small
# checkpoint_path: outputs/full_ft/checkpoint-1410
# epochs: 5
# batch_size: 6
# learning_rate: 5e-05
# train_samples: 1689
# val_samples: 211
# test_samples: 212
# device: cpu
# training_runtime_seconds: 4433.6
# total_parameters: 172119424
# trainable_parameters: 172119424
# BLEU: 0.17
# ROUGE_L: 0.0
# CFS_avg: 1.0
# serving_role: default
# ------------------------------------------------------------
# model_type: lora
# base_model: google/mt5-small
# checkpoint_path: outputs/lora/checkpoint-1272
# epochs: 6
# batch_size: 8
# learning_rate: 0.0001
# train_samples: 1689
# val_samples: 211
# test_samples: 212
# device: cpu
# training_runtime_seconds: 1928.01
# total_parameters: 300520832
# trainable_parameters: 0
# BLEU: 0.03
# ROUGE_L: 0.0
# CFS_avg: 1.0
# ...

# %% [markdown]
# ## Step 2: Inspect the summary table

# %%
import pandas as pd
df = pd.read_csv('results_summary.csv')
df
# Out:
#   model_type        base_model                  checkpoint_path  epochs  \
# 0    full_ft  google/mt5-small  outputs/full_ft/checkpoint-1410       5
# 1       lora  google/mt5-small     outputs/lora/checkpoint-1272       6
#
#    batch_size  learning_rate  train_samples  val_samples  test_samples device  \
# 0           6        0.00005           1689          211           212    cpu
# 1           8        0.00010           1689          211           212    cpu
#
#    training_runtime_seconds  total_parameters  trainable_parameters  BLEU  \
# 0                   4433.60         172119424             172119424  0.17
# 1                   1928.01         300520832                     0  0.03
#
#    ROUGE_L  CFS_avg serving_role
# 0      0.0      1.0      default
# 1      0.0      1.0     optional
